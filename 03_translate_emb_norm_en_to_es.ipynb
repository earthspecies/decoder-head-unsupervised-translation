# %%
from decoder_head.core import *
from fastai2.text.all import *

# %%
class PermuteEmbedding(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, padding_idx):
        super().__init__()
        
        self.num_embeddings = num_embeddings
        self.embedding_dim = embedding_dim
        self.padding_idx = padding_idx
        
        # to conform to nn.Embedding api
        self.max_norm=None
        self.norm_type=2.0
        self.scale_grad_by_freq=False
        self.sparse = False

        self.weight = nn.Parameter( torch.Tensor(num_embeddings, embedding_dim) )
        nn.init.kaiming_uniform_(self.weight)
        self.p = nn.Parameter( torch.eye(self.num_embeddings) )
        self.p.requires_grad = False
        
        self.reset_parameters()
        
    def forward(self, words):
        return F.embedding(words, self.p @ self.normalized_weight())
    
    def normalized_weight(self):
        w1 = self.weight / self.weight.norm(dim=1).unsqueeze(1)
        w2 = w1 - w1.mean(0)
        w3 = w2 / w2.norm(dim=1).unsqueeze(1)
        return w3
        
    def reset_parameters(self): pass

import decoder_head.core
decoder_head.core.PermuteEmbedding = PermuteEmbedding

# %%
vocab_en= make_vocab(pd.read_pickle('data/en-100_tok/counter.pkl'), max_vocab=4000)
vocab_es= make_vocab(pd.read_pickle('data/es-100_tok/counter.pkl'), max_vocab=4000)

# %%
path = 'data/en-100_tok/'
mult = 4
bs = 80
seq_len = 70

lm = DataBlock(blocks=(TextBlock(vocab=vocab_en, is_lm=True),),
                get_x=read_tokenized_file,
                get_items=partial(get_text_files, folders=['train', 'valid']),
                splitter=FuncSplitter(lambda itm: itm.parent.name == 'valid'))

dbunch_lm = lm.databunch(path, path=path, bs=bs, seq_len=seq_len)

# %%
learn = language_model_learner(
    dbunch_lm,
    pAWD_LSTM,
    opt_func=opt,
    pretrained=False,
    config=awd_lstm_lm_config,
    drop_mult=0.1,
    metrics=[accuracy, top_k_accuracy]
)

# %%
learn.load('emb_norm_rows_columns') # en LM

# %%
with open('data/en-es.txt') as f:
    en_es = f.readlines()
    
en_es = [l.strip() for l in en_es]

en_es_dict = defaultdict(list)

for l in en_es:
    source, target = l.split()
    en_es_dict[source].append(target)

# %%
len(en_es_dict)
# Out:
# 93084

# %% [markdown]
# Check that we have the source word in the model trained on English

# %%
vocab_en_set = set(vocab_en)
en_es_dict = {k: v for k, v in en_es_dict.items() if k in vocab_en_set}

# %%
len(en_es_dict)
# Out:
# 3475

# %% [markdown]
# Make sure we have the target word in Spanish

# %%
vocab_es_set = set(vocab_es)
en_es_dict = {k: vocab_es_set.intersection(set(v)) for k, v in en_es_dict.items() if vocab_es_set.intersection(set(v))}

# %%
len(en_es_dict)
# Out:
# 2451

# %% [markdown]
# Attemp translation from English to Spanish

# %%
learn.model[0].encoder.weight.requires_grad
# Out:
# True

# %%
learn.optimize_permutation()

# %%
learn.model[0].encoder.weight.requires_grad
# Out:
# False

# %%
nn.init.kaiming_normal_(learn.model[0].encoder.p);

# %%
learn.model[0].encoder.weight.data = torch.load('data/embeddings_es.torch').data

# %%
learn.model[0].encoder.p.requires_grad
# Out:
# True

# %%
learn.model[0].encoder.weight.requires_grad
# Out:
# False

# %% [markdown]
# We now have an English LM with Spanish embeddings loaded. Let's see how we do on translation.
#
# One thing worth keeping in mind are the missing English words from the Spanish vocabulary. This is an interesting situation and makes the task even harder.

# %%
learn.loss_func = lambda preds, targs: aza_loss(learn, preds, targs)

# %%
learn.fit_one_cycle(1, 1e-3,  moms=(0.8, 0.7, 0.8), wd=1e-7)
# Out:
# epoch     train_loss  valid_loss  accuracy  top_k_accuracy  time
# █

# %%
learn.fit_one_cycle(1, 1e-3,  moms=(0.8, 0.7, 0.8), wd=1e-7)

# %%
# learn.save('pLSTM_emb_norm_en-es')

# %%
learn.load('pLSTM_emb_norm_en-es')

# %%
learn.validate()
# Out:
# █
# (#3) [5.05198335647583,0.25118646025657654,0.4493016004562378]

# %%
def top_n_translation_acc(top_n=1):
    p = learn.model[0].encoder.p
    hits = 0
    for k, v in en_es_dict.items():
        idx_en = vocab_en.index(k)
        for vv in v:
            idx_es = vocab_es.index(vv)
            if idx_es in p[idx_en].argsort(descending=True)[:top_n]:
                hits += 1
#                 print(k, vv)
                break
    return hits/len(en_es_dict)

# %%
top_n_translation_acc(100)
# Out:
# 0.031007751937984496

# %%
def top_n_translation_acc(top_n=1):
    p = learn.model[0].encoder.p
    hits = 0
    for k, v in en_es_dict.items():
        idx_en = vocab_en.index(k)
        for vv in v:
            idx_es = vocab_es.index(vv)
            if idx_es in p[idx_en].argsort(descending=True)[:top_n]:
                hits += 1
                print(k, [vocab_es[i] for i in p[idx_en].argsort(descending=True)[:5]])
                break
    return hits/len(en_es_dict)

# %%
en_es_dict['have']
# Out:
# {'han', 'tener', 'tienen'}

# %%
top_n_translation_acc(5)
# Out:
# food ['enlaces', 'comida', 'producción', 'plata', 'cobre']
# illinois ['duró', 'catedral', 'vivienda', 'estreno', 'illinois']
# looking ['paulo', 'lorenzo', 'aires', 'buscando', 'cobre']
# 0.0012239902080783353

# %%
def top_n_translation_acc(top_n=1):
    p = learn.model[0].encoder.p
    hits = 0
    for k, v in en_es_dict.items():
        idx_en = vocab_en.index(k)
        print(k, [vocab_es[i] for i in p[idx_en].argsort(descending=True)[:5]])
        for vv in v:
            idx_es = vocab_es.index(vv)
            if idx_es in p[idx_en].argsort(descending=True)[:top_n]:
                hits += 1
                break
    return hits/len(en_es_dict)

# %%
top_n_translation_acc(100)
# Out:
# the ['«', 'nacionalidad', 'creció', 'argentina', 'wisconsin']
# and ['sin', 'nueva', 'obra', 'opinión', 'aunque']
# was ['naciones', 'islas', 'estados', 'superar', 'de']
# for ['cargo', 'elaboración', 'elección', 'sesión', 'publicación']
# that ['o', 'oportunidades', 'negó', 'cargo', 'guerra']
# with ['publicación', 'revista', 'cargo', 'gestión', 'elección']
# from ['basados', 'casos', 'convirtiéndose', 'entre', 'posición']
# this ['plena', 'cercana', 'alta', 'u', 'misión']
# his ['unidad', 'fuente', 'unión', 'principal', 'reserva']
# not ['bajo', 'minas', 'santa', 'clase', 'carne']
# are ['xxunk', 'fuerza', 'unidad', 'minas', 'mujeres']
# talk ['actividades', 'resto', 'favor', 'lucha', 'contexto']
# which ['u', 'carta', 'expedición', 'mano', 'o']
# also ['tribus', 'mujeres', 'renta', 'fuerzas', 'minas']
# has ['plena', 'oposición', 'inteligencia', 'coalición', 'democracia']
# were ['fuerza', 'renta', 'minas', 'islas', 'autoridad']
# but ['búsqueda', 'derechos', 'guerra', 'opinión', 'carta']
# have ['plena', 'renta', 'democracia', 'inteligencia', 'oposición']
# one ['el', 'princesa', 'otra', 'al', 'otro']
# new ['aparte', 'propia', 'misma', 'sin', 'era']
# first ['razón', 'suprema', 'católica', 'religiosa', 'baja']
# page ['producto', 'xiv', 'man', 'completamente', 'negro']
# you ['nacida', 'esperanza', 'armada', 'originalmente', 'situada']
# they ['asamblea', 'autoridad', 'convención', 'franja', 'operación']
# had ['plena', 'renta', 'coalición', 'oposición', 'fuerzas']
# article ['éste', 'factores', 'incidente', '1959', 'ésta']
# who ['cercano', 'cercana', 'estrecho', 'simple', 'u']
# all ['griega', 'cristiana', 'ciencia', 'hay', 'madre']
# their ['xxunk', 'laguna', 'unidad', 'caja', 'boca']
# there ['busca', 'futuro', 'todo', 'poder', 'él']
# been ['ave', 'santa', 'fuente', 'principal', '“']
# made ['india', 'alta', 'guerra', "'", 'civil']
# its ['unidad', 'xxunk', 'piedras', 'laguna', 'unión']
# people ['todo', 'soberanía', 'origen', 'hacia', 'relaciones']
# may ['0.02', 'diferencia', 'amenaza', 'oposición', 'condiciones']
# after ['puestos', 'ensayos', 'cambio', 'artículos', 'encuentros']
# other ['corresponden', 'son', 'marca', 'abarca', 'según']
# should ['bajo', 'pena', 'distancia', 'veces', 'aguas']
# two ['hombres', 'alemania', 'madre', 'fuerza', 'princesa']
# her ['principal', 'xxmaj', 'islas', 'baja', 'unidad']
# can ['pérdida', 'menor', 'contra', 'bajo', 'menos']
# more ['unión', 'posee', 'reserva', 'unidad', 'comprende']
# she ['fácil', 'difícil', 'rápido', 'allá', 'elevado']
# about ['propuesta', 'obteniendo', 'convirtiéndose', 'tesis', 'cifra']
# when ['casos', 'tales', 'búsqueda', 'campos', 'manera']
# time ['hacia', 'posteriormente', 'definitivamente', 'león', 'mayor']
# team ['hacia', 'desde', 'en', 'durante', 'mas']
# american ['sólo', 'solo', 'pocos', 'serían', 'generalmente']
# such ['red', 'xxunk', 'mesa', 'fábrica', 'mezcla']
# only ['propuesta', 'coalición', 'plena', 'clase', 'oposición']
# some ['madre', 'princesa', 'mujer', 'hombres', 'griega']
# see ['creación', 'fabricación', 'realización', 'versión', 'o']
# united ['actualidad', 'tan', 'crítica', 'críticos', 'cabe']
# years ['cultura', 'geografía', 'legado', 'composición', 'mejor']
# school ['”', 'turismo', 'principal', '»', 'hacia']
# world ['también', 'asimismo', 'mas', 'igualmente', 'adicional']
# university ['ahora', 'desde', 'vive', 'luego', 'actualmente']
# during ['estudios', 'trabajos', 'artículos', 'ensayos', 'cursos']
# out ['otra', 'mexicana', 'el', 'nº', 'dominicana']
# state ['otra', 'desde', 'mas', 'también', 'otros']
# states ['actualmente', 'originalmente', 'oficialmente', 'asociado', 'día']
# national ['misma', 'actualidad', 'aparte', 'segunda', 'era']
# year ['cultura', 'definitivamente', 'nuevamente', 'posteriormente', 'asociado']
# city ['”', 'hacia', 'desde', 'posteriormente', 'actualmente']
# used ['pan', 'atrás', 'dolor', 'azúcar', 'cualquier']
# then ['corte', 'caballería', 'renta', 'artillería', 'clase']
# county ['arquitectura', 'conservación', 'importancia', 'teología', 'reconstrucción']
# where ['casos', 'dichos', 'campos', 'tales', 'guerra']
# will ['bajo', 'oposición', 'clase', 'frente', 'línea']
# what ['cuyas', 'u', 'general', 'lejos', 'guerra']
# any ['comunidad', 'unidad', 'antigua', 'quinta', 'confederación']
# these ['confederación', 'royal', 'autoridad', 'unidad', 'reserva']
# january ['corresponden', 'órgano', '–', 'creek', 'volumen']
# march ['problema', 'corresponden', '–', 'volumen', 'órgano']
# august ['corresponden', 'problema', '–', 'daño', '_']
# july ['corresponden', '–', 'problema', 'volumen', 'órgano']
# being ['ave', 'radio', '“', 'minas', 'islas']
# film ['hacia', 'libre', 'nuevamente', 'como', 'asociado']
# him ['company', 'pan', 'origen', 'voz', 'león']
# many ['madre', 'mujer', 'princesa', 'hermana', 'única']
# south ['cabe', 'como', 'asimismo', 'actualidad', 'igualmente']
# september ['–', 'órgano', 'volumen', 'problema', '_']
# like ['creación', 'comedia', 'versión', 'categoría', 'edición']
# between ['existen', 'cabe', 'existe', 'resultó', 'podemos']
# october ['–', 'corresponden', 'problema', '”', 'órgano']
# three ['hombres', 'probablemente', 'alemania', 'princesa', 'según']
# june ['–', '—', 'corresponden', 'órgano', 'problema']
# well ['producción', 'composición', 'radio', 'recibe', 'pesca']
# use ['otro', 'el', 'vasco', 'otra', 'dr']
# war ['”', 'asociado', 'principal', 'turismo', 'interior']
# under ['siglas', 'publicado', 'estudios', 'casos', 'trabajó']
# them ['pan', 'león', 'company', 'comida', 'voz']
# april ['–', '—', 'corresponden', 'industrias', 'órgano']
# born ['éste', 'ahí', 'negocios', 'especial', 'bajos']
# december ['corresponden', 'problema', '–', 'volumen', 'órgano']
# link ['procedimiento', 'pie', 'periodo', 'compromiso', 'largo']
# while ['manera', 'tales', 'campos', 'incluyendo', 'volúmenes']
# later ['pan', 'moda', 'cocina', 'terror', 'maíz']
# part ['otro', 'otra', 'otras', 'nuestro', 'princesa']
# november ['–', '”', '—', 'corresponden', 'problema']
# players ['alta', 'espíritu', 'imperio', 'carácter', 'alma']
# list ['el', 'nº', 'al', 'luego', 'desde']
# following ['conferencias', 'gestión', 'campeonatos', 'videojuegos', 'sesión']
# february ['corresponden', 'órgano', 'industrias', 'creek', '—']
# known ['mezcla', 'fabricación', 'forma', 'xxunk', 'formando']
# second ['razón', 'reina', 'aun', 'católica', 'religiosa']
# name ['cómo', 'origen', 'dominicana', 'argentino', 'mexicano']
# group ['nº', 'otro', 'otra', 'vasco', 'dr']
# history ['principal', 'cultura', 'social', 'arquitectura', 'militar']
# series ['idioma', 'cultura', 'historia', 'mitología', 'nº']
# just ['organización', 'dictadura', 'revolución', 'monarquía', 'santa']
# north ['cabe', 'actualidad', 'asimismo', 'como', 'algunos']
# work ['hasta', 'hacia', 'luego', 'inmediatamente', 'desde']
# before ['artículos', 'cargos', 'compuestos', 'ensayos', 'ejemplares']
# since ['puestos', 'ejemplares', 'acuerdo', 'renuncia', 'xxfld']
# season ['cultura', 'turismo', '—', 'asociado', 'libre']
# both ['hay', 'existe', 'existen', 'había', 'podemos']
# high ['madre', 'griega', 'escritores', 'mitología', 'segunda']
# through ['artículos', 'trabajos', 'ensayos', 'estudios', 'cargos']
# district ['falleció', 'presidente', 'don', 'estudió', 'casado']
# now ['harry', 'high', 'comedia', 'novela', 'novelas']
# comments ['agustín', '1966', 'normalmente', 'ampliamente', 'carl']
# because ['nuestro', 'todo', 'mexicana', 'ibérica', 'nuestra']
# football ['opinión', 'artículos', 'alrededor', 'prensa', 'situación']
# music [',', 'hacia', 'médica', 'principalmente', 'directamente']
# century ['cultura', 'raza', 'arquitectura', '—', 'león']
# league ['actividad', 'atención', 'educación', 'electricidad', 'deuda']
# debate ['históricos', 'fenómeno', 'secundarios', 'escribir', 'través']
# title ['mayor', 'dominicana', 'finalmente', 'universitaria', 'menor']
# articles ['mejorar', 'promover', 'habilidad', 'relación', 'religiosos']
# john ['actualidad', 'leyenda', 'segunda', 'versión', 'editorial']
# same ['des', 'galería', 'for', 'and', 'escuela']
# including ['programación', 'actualidad', 'publicación', 'versión', 'creación']
# could ['coalición', 'igualdad', 'oposición', 'candidatura', 'isleños']
# english ['generalmente', 'contienen', 'refugio', 'respuesta', 'lugar']
# album ['nuevamente', 'libre', 'definitivamente', 'argentino', 'colombiano']
# number ['el', 'educación', 'mujeres', 'religión', 'princesa']
# against ['participó', 'resultó', 'como', 'colaboró', 'cabe']
# family ['mejor', 'hacia', 'al', 'principal', 'incluso']
# based ['económicas', 'internacional', 'europeas', 'académico', 'europeo']
# area ['luego', '”', 'turismo', 'posteriormente', 'productor']
# york ['actualidad', 'aun', 'dado', 'aparte', 'parece']
# life ['cultura', 'principal', 'literatura', 'hacia', 'arquitectura']
# british ['pocas', 'fuerzas', 'sólo', 'pequeña', 'cifra']
# international ['misma', 'universidad', 'actualidad', 'segunda', 'ciudad']
# game ['hacia', 'libre', 'posteriormente', 'desde', 'asociado']
# above ['concentración', 'trabajos', 'riesgo', 'variaciones', 'estudios']
# club ['sobre', 'hacia', 'rápidamente', 'en', 'durante']
# your ['india', 'aunque', 'cuya', 'pero', 'que']
# until ['casos', 'resultó', 'tales', 'convirtiéndose', 'artículos']
# early ['apenas', 'vientos', 'ocurre', 'ocurrió', 'casi']
# best ['razón', 'muchos', 'tan', 'cabe', 'muchas']
# west ['cabe', 'también', 'como', 'asimismo', 'otra']
# house ['portugués', 'argentino', 'luego', 'turismo', '”']
# company ['señor', 'doctor', '”', 'católico', 'futuro']
# general ['cabe', 'aparte', 'anteriormente', 'actualidad', 'como']
# left ['durante', 'para', 'muchas', 'o', 'etc']
# very ['florida', 'fuente', 'causa', 'región', 'pertenecían']
# here ['síntesis', 'restauración', 'expansión', 'recuperación', 'moda']
# don ['algunos', 'mala', 'muchas', 'pocas', 'algunas']
# living ['esclavos', 'órganos', 'minerales', 'pueblos', 'bosques']
# day ['león', 'nuevamente', 'posteriormente', '—', 'definitivamente']
# several ['unidad', 'fuerza', 'única', 'confederación', 'federación']
# place ['hacia', 'hasta', 'allí', 'petróleo', 'mayor']
# party ['”', 'hacia', '»', '?', 'do']
# college ['»', 'don', 'principal', '”', 'capital']
# result ['otro', 'xv', 'estadounidense', 'luego', 'civil']
# keep ['ingreso', '²', 'participación', 'candidatura', 'instalación']
# four ['probablemente', 'alemania', 'hombres', 'princesa', 'madre']
# subsequent ['según', 'georgia', 'símbolo', 'cruz', 'grupos']
# even ['monarquía', 'rebelión', 'comunidad', 'coalición', 'clase']
# class ['letras', 'descrito', '”', '?', 'finalmente']
# government ['al', 'productor', 'señor', 'católico', 'a']
# how ['posición', 'manera', 'formas', 'búsqueda', 'buena']
# called ['ahí', 'aquí', 'casos', 'aires', 'únicamente']
# did ['independiente', 'global', '²', 'libre', 'poblacional']
# each ['antigua', 'única', 'verdadera', 'larga', 'quinta']
# found ['ciertos', 'productos', 'alimentos', 'ciertas', 'muchas']
# center ['”', 'clima', 'turismo', 'señor', '»']
# per ['hecha', 'formada', 'dedicada', 'compuesta', 'cubierta']
# style ['la', 'costumbres', 'política', 'luego', 'latina']
# long ['recibe', 'ciencia', 'lengua', 'pan', 'dr']
# country ['rápidamente', 'directamente', 'hacia', 'nuevamente', 'asociado']
# back ['cómo', 'algunos', 'algunas', 'ciertos', 'consecuencias']
# way ['cómo', 'cuidado', 'social', 'incluso', 'algunos']
# does ['independiente', 'global', '²', 'deportivo', 'internacional']
# end ['otro', 'nº', 'luego', 'al', 'después']
# make ['revista', 'time', 'civil', 'revistas', 'art']
# public ['para', 'se', 'es', 'florida', 'composición']
# played ['64', '1950', 'guerra', '1960', 'buenos']
# won ['estudios', 'ensayo', 'reformas', 'páginas', 'gobiernos']
# another ['según', 'opción', 'marca', 'ocurrió', 'fuente']
# released ['1990', '1980', '1970', '1983', 'presidencial']
# support ['algunos', 'algunas', 'incluso', 'otros', 'también']
# games ['león', 'cultura', 'turismo', 'progreso', 'tratamiento']
# former ['apareció', 'actuó', 'había', 'figura', 'interpretó']
# those ['¡', 'inmigrantes', 'capital', 'península', 'áfrica']
# films ['arquitectura', 'expansión', 'teología', 'economía', 'senador']
# church ['turismo', 'allí', '”', 'desde', 'deporte']
# east ['cabe', 'también', 'otra', 'hay', 'existen']
# line ['origen', 'posteriormente', 'consumo', 'luego', 'company']
# major ['existía', 'región', 'santa', 'villa', 'misma']
# members ['otro', 'mitología', 'otras', 'historia', 'princesa']
# good ['por', 'gracias', 'principalmente', 'para', 'mediante']
# much ['madre', 'tercera', 'princesa', 'otra', 'hay']
# image ['todo', 'española', 'xv', 'fundada', 'xvi']
# show ['nuevamente', 'definitivamente', 'hacia', 'rápidamente', 'asociado']
# still ['minas', 'bajo', 'artillería', 'esclavos', 'islas']
# below ['pasos', 'trabajos', 'concentración', 'estudios', 'contenido']
# town ['actualmente', 'desde', 'luego', 'portugués', '”']
# last ['política', 'religiosa', 'cristiana', 'razón', 'alta']
# system ['león', 'cultura', 'desarrollo', 'clima', 'comportamiento']
# right ['cómo', 'castellano', 'portugués', 'social', 'después']
# song ['libre', 'hacia', 'médica', 'definitivamente', 'pública']
# notable ['james', 'rasgos', 'harry', 'animales', 'gas']
# section ['yo', 'otro', 'socialista', 'guitarrista', 'b']
# single ['pública', 'paulo', 'pan', 'dominicana', 'latina']
# included ['elecciones', '1990', '1970', '1980', '1950']
# home ['origen', 'música', 'educación', 'voz', 'finalmente']
# women ['fin', 'hacia', 'y', 'en', 'sobre']
# television ['xxmaj', 'moneda', ',', 'excepción', '(']
# member ['otro', 'otra', 'uno', 'el', 'mexicana']
# goals ['productos', 'alimentos', 'sangre', 'cobre', 'cerámica']
# sources ['expresión', 'agrícola', 'figuras', 'intelectual', 'costumbres']
# book ['simplemente', 'finalmente', 'mexicano', 'continúa', 'también']
# station ['progreso', 'derecho', 'secundarios', 'allí', 'mantenimiento']
# order ['adelante', 'cómo', 'atrás', 'vez', 'matrimonio']
# old ['como', 'actualidad', 'figura', 'concepción', 'también']
# information ['sociales', 'contexto', 'depende', 'entender', 'renacimiento']
# set ['política', 'económico', 'humano', 'esclavos', 'sexual']
# own ['—', ',', 'opera', '―', 'pesca']
# text ['aire', 'piano', 'lo', 'canto', 'latín']
# band ['frente', 'rápidamente', 'fin', 'dentro', 'hacia']
# point ['social', 'española', 'pan', 'moral', 'pública']
# local ['xxunk', 'trinidad', 'dioses', 'georgia', 'marca']
# around ['convertido', 'convirtiéndose', 'realizado', 'basados', 'siglas']
# river ['león', 'amerindios', 'turismo', 'junto', 'juntos']
# top ['mujeres', 'educación', 'religiosa', 'princesa', 'organizaciones']
# main ['judíos', 'ninguna', 'musulmanes', 'ciento', 'tribus']
# language ['más', 'completamente', 'juntos', 'responsable', 'costumbres']
# french ['fuerzas', 'fuerza', 'alas', 'piedras', 'tropas']
# named ['casos', 'ahí', 'restos', 'regreso', 'manera']
# note ['ser', 'ii', 'xv', 'considerar', 'plantas']
# career ['arquitectura', 'cultura', 'industria', 'principal', 'agricultura']
# original ['moneda', 'todavía', 'virginia', 'judíos', 'aún']
# age ['después', 'luego', 'idioma', 'portugués', 'nº']
# service ['origen', 'comportamiento', 'comida', 'mayor', 'león']
# established ['inmediato', 'guerra', 'periódicos', 'generales', 'negocios']
# located ['unidos', 'hasta', 'generales', 'militares', 'dichas']
# said ['dominicana', 'definitivamente', 'oficialmente', 'democrática', 'raíces']
# website ['córdoba', 'lima', 'nombrado', 'universitario', 'catalán']
# population ['educación', 'capital', 'política', 'más', 'mayor']
# air ['actualidad', 'tan', 'aparte', 'misma', 'gente']
# german ['fuerzas', 'tropas', 'cierto', 'pocas', 'agente']
# law ['hacia', 'luego', '/', 'composición', 'otros']
# military ['son', 'fuente', 'carne', 'cocina', 'composición']
# great ['alrededor', 'había', 'siendo', 'aparte', 'aunque']
# clubs ['playa', 'transición', 'construcciones', 'expansión', 'destrucción']
# published ['45', '55', '44', '37', '1920']
# president ['cabe', 'otra', 'actualmente', 'anteriormente', 'hay']
# park ['allí', 'turismo', 'funcionamiento', 'paisaje', 'cultivo']
# official ['georgia', 'dioses', 'estados', 'existía', 'john']
# case ['company', 'psoe', 'pan', 'argentino', 'alemán']
# london ['actualmente', 'testamento', 'origen', 'geografía', 'legado']
# times ['impacto', 'efecto', 'tratamiento', 'progreso', 'abogado']
# although ['tales', 'esos', 'sectores', 'búsqueda', 'ejemplares']
# small ['dioses', 'carne', 'xxunk', 'composición', 'familia']
# third ['razón', 'muchos', 'muchas', 'ciertos', 'aun']
# different ['xxunk', 'piedras', 'fuente', 'mancha', 'laguna']
# due ['adelante', 'clases', 'cómo', 'algunos', 'grado']
# get ['comedia', 'moda', 'novela', 'reforma', 'animación']
# village ['guitarrista', 'español', 'negro', 'italiano', 'argentino']
# art ['composición', 'naturaleza', 'salud', 'música', 'ubicación']
# player ['atrás', 'algún', 'ese', 'matrimonio', 'estudió']
# final ['religiosa', 'familia', 'judía', 'política', 'ley']
# community ['música', 'más', 'posteriormente', 'también', 'igualmente']
# again ['petróleo', 'azúcar', 'comida', 'mayor', 'alimentos']
# began ['dolor', 'poco', 'papel', 'haber', 'blanco']
# army ['otro', 'ingeniero', 'doctor', 'a', 'señor']
# award ['paulo', 'méxico', 'continúa', 'finalmente', 'hoy']
# without ['dirigida', 'familia', 'compañía', 'editorial', 'clase']
# death ['cultura', 'hacia', 'mayor', 'león', 'luego']
# built ['hasta', 'animales', 'petróleo', 'alimentos', 'guerra']
# men ['hacia', 'a', 'mucha', 'origen', 'desde']
# large ['vive', 'representa', 'united', 'irán', 'conoce']
# site ['casado', 'matrimonio', 'señor', 'luego', 'atrás']
# using ['clase', 'new', 'red', 'periódicos', 'cuentos']
# white ['tiene', 'presenta', 'posee', 'formando', 'siendo']
# along ['dos', 'siglas', 'n', 'tres', 'ex']
# five ['probablemente', 'reina', 'originaria', 'princesa', 'única']
# central ['cabe', 'aparte', 'actualidad', 'hubo', 'asunción']
# road ['impacto', 'secreto', 'legado', 'reconocimiento', 'efecto']
# children ['mejor', 'origen', '”', 'oficialmente', 'principalmente']
# free ['siendo', 'aunque', 'para', 'mientras', 'es']
# took ['organizaciones', 'sociedades', 'conferencias', 'sociales', 'asociaciones']
# england ['”', 'une', 'destino', 'conocimiento', 'center']
# include ['textos', 'novelas', 'escritos', 'videojuegos', 'míchigan']
# association ['”', 'destino', 'presidente', 'sede', 'centro']
# down ['papel', 'moda', 'noticias', 'estudios', 'inmediato']
# given ['conferencias', 'civil', 'man', 'especial', 'general']
# source ['uno', 'la', 'dr', 'historia', 'nuestra']
# california ['>', 'funcionamiento', 'geografía', 'legislatura', 'une']
# man ['hacia', 'pan', 'cómo', 'origen', 'a']
# version ['nº', 'otro', 'otra', 'autónoma', 'mexicana']
# written ['55', '45', '1990', 'c.', '34']
# created ['ensayo', 'revistas', 'cine', 'conferencias', 'televisión']
# media ['cerámica', 'mediante', ',', 'respecto', 'arquitectura']
# black ['se', 'siendo', 'es', 'está', 'aparece']
# though ['búsqueda', 'negó', 'contra', 'esos', 'guerra']
# report ['fracaso', 'chile', 'tratamiento', 'canto', 'realizar']
# building ['hacia', 'consumo', 'pan', 'terror', 'teatro']
# take ['necesaria', 'conferencias', 'crítica', 'organizaciones', 'publicidad']
# division ['día', 'señor', 'destino', 'cuidado', '?']
# having ['oposición', 'new', 'coalición', 'plena', 'provincias']
# king ['otra', 'como', 'cabe', 'otro', 'también']
# stadium ['cultivo', 'allí', 'conservación', 'paisaje', '»']
# died ['hasta', 'petróleo', 'unidos', 'carbón', 'mayor']
# ship ['contemporáneo', 'católico', 'mexicano', 'como', 'hacia']
# research ['expresión', 'salud', 'composición', 'naturaleza', 'personas']
# record ['pan', 'terror', 'ciencia', 'desde', 'hacia']
# places ['cabo', 'fundamentalmente', 'petróleo', 'electricidad', 'nacimiento']
# cup ['electricidad', '”', 'maíz', 'gas', 'fruto']
# records ['”', 'turismo', 'clima', '?', 'destino']
# often ['minas', 'xxunk', 'isla', 'corte', 'unión']
# few ['autoridad', 'fuerzas', 'cortes', 'unidad', 'asociación']
# received ['editorial', 'revista', 'universidades', 'art', 'revistas']
# side ['nº', 'otro', 'otra', 'al', 'luego']
# power ['origen', 'vive', 'otros', 'atrás', 'después']
# education ['cerámica', 'fauna', 'maíz', 'arquitectura', 'flora']
# know ['abierta', 'fundamentalmente', 'dedicada', 'integrada', 'alta']
# category ['inicialmente', 'inmediatamente', 'ampliamente', 'normalmente', 'rápidamente']
# water ['composición', 'pan', 'danza', 'comida', 'belleza']
# political ['piedras', 'laguna', 'pesca', 'son', 'mancha']
# species ['historia', 'salud', 'company', 'geografía', 'fútbol']
# field ['formación', 'más', 'producción', 'danza', 'composición']
# near ['cabe', 'participó', 'resultó', 'además', 'colaboró']
# australia ['”', 'une', 'destino', 'conocimiento', 'dirige']
# video ['necesaria', 'científica', 'legal', 'económica', 'libre']
# need ['cómo', 'adelante', 'castellano', 'español', 'decir']
# island ['”', 'turismo', '?', 'deporte', '»']
# form ['vasco', 'xii', 'iv', 'ii', 'xv']
# find ['publicaciones', 'asociaciones', 'revistas', 'películas', 'ideas']
# served ["'", 'ambas', 'formando', 'hierro', 'donde']
# play ['pensamiento', 'moda', 'aires', 'terror', 'finalmente']
# project ['futuro', 'activo', 'progreso', 'arte', 'económico']
# radio ['xxmaj', 'originaria', 'baja', '[', 'casi']
# works ['tecnología', 'áfrica', 'medio', 'televisión', 'origen']
# proposed ['man', 'ii', 'misiones', 'ix', 'penal']
# every ['cercana', 'verdadera', 'antigua', 'comunidad', 'cifra']
# development ['mitología', 'literatura', 'política', 'cultura', 'educación']
# example ['oeste', 'dr', 'psoe', 'británico', 'técnica']
# live ['desde', 'durante', 'química', ',', '…']
# union ['>', ']', 'funciona', 'apenas', 'todavía']
# india ['conocimiento', 'dirige', '?', 'une', '>']
# next ['privada', 'pública', 'administrativa', 'abierta', 'rápida']
# special ['baja', 'misma', 'carolina', 'provincia', 'había']
# court ['a', 'al', 'vive', 'don', 'portugués']
# region ['”', 'turismo', 'más', '?', 'posteriormente']
# little ['pese', 'costa', 'cuyo', 'cuya', 'aparte']
# short ['esperanza', 'verde', 'moral', 'física', 'marrón']
# william ['leyenda', 'actualidad', 'segunda', 'versión', 'editorial']
# province ['ahora', 'poeta', 'guitarrista', 'secundaria', 'doctor']
# western ['cabe', 'apareció', 'hubo', 'aparte', 'actualidad']
# son ['también', 'como', 'oficialmente', 'argentino', 'actualmente']
# france ['destino', 'une', 'turismo', '”', '?']
# council ['destino', '”', 'señor', 'día', '?']
# others ['turismo', 'economía', 'patrimonio', '.', 'progreso']
# royal ['misma', 'actualidad', 'aparte', 'segunda', 'propia']
# current ['palabra', 'película', 'monumentos', 'probablemente', 'edward']
# street ['reconocimiento', 'destino', 'funcionamiento', 'establecimiento', 'obispo']
# full ['cristiana', 'griega', 'religiosa', 'princesa', 'reina']
# red ['aparte', 'era', 'actualidad', 'india', 'alrededor']
# too ['realizando', 'california', 'región', 'dedicada', 'pasando']
# department ['ahora', 'nunca', 'vive', 'yo', 'católica']
# san ['actualidad', 'segunda', 'versión', 'misma', 'década']
# help ['dos', 'tres', 'cuatro', 'quien', 'sin']
# among ['puestos', 'o', 'cargos', 'medallas', 'cursos']
# james ['versión', 'leyenda', 'editorial', 'crónica', 'actualidad']
# open ['ropa', 'guitarra', 'sexo', 'carne', 'comida']
# force ['”', 'relaciones', 'mejor', 'consecuencias', 'influencia']
# position ['mayor', 'hacia', 'company', 'hasta', 'allí']
# head ['letras', 'influencias', 'idioma', 'nº', 'productor']
# director ['también', 'cabe', 'actualmente', 'existe', 'recientemente']
# father ['artístico', 'como', 'también', 'contemporáneo', 'nuevamente']
# track ['principalmente', 'rápidamente', 'parcialmente', 'directamente', 'fundamentalmente']
# canada ['dirige', 'une', '”', 'conocimiento', 'fin']
# never ['formada', 'trinidad', 'cifra', 'compuesta', 'colonia']
# george ['versión', 'oficial', 'editorial', 'leyenda', 'actualidad']
# level ['después', 'cultura', 'negro', 'influencias', 'educación']
# late ['apenas', 'ocurrió', 'ocurre', 'respuesta', 'pocos']
# summer ['después', 'historia', 'mitología', 'música', 'también']
# society ['”', 'señor', 'clima', 'actualmente', 'deporte']
# office ['economía', 'patrimonio', 'turismo', 'fauna', 'educación']
# period ['cultura', 'política', 'historia', 'libre', 'mayor']
# championship ['turismo', '”', 'patrimonio', '»', '²']
# round ['—', 'influencias', 'nº', 'mujeres', 'do']
# story ['posteriormente', 'finalmente', 'luego', 'origen', 'actualmente']
# songs ['finalmente', 'a', '•', 'paulo', 'principalmente']
# various ['hombres', 'tenían', 'georgia', 'unidad', 'franja']
# days ['geografía', 'cultura', '–', 'mejor', 'actor']
# land ['pan', 'gas', 'cobre', 'finalmente', 'posteriormente']
# business ['escultura', '.', 'enlaces', 'fauna', 'fiestas']
# reason ['paulo', 'juntos', 'unido', 'obligado', 'fuera']
# america ['”', 'destino', 'une', 'dirige', '?']
# million ['raza', 'comida', 'producción', 'agricultura', 'actividad']
# european ['célula', 'cifra', 'columna', 'murieron', 'sólo']
# term ['pan', 'aires', 'insectos', 'hasta', 'arena']
# six ['probablemente', 'según', 'hombres', 'alemania', 'aunque']
# post ['cristiana', 'humana', 'religiosa', 'física', 'católica']
# produced ['tropical', 'naciones', 'idiomas', 'china', 'colonial']
# making ['máxima', 'per', 'medios', 'guerra', 'libros']
# subject ['idioma', 'atrás', 'matrimonio', 'adelante', 'santo']
# young ['asunción', 'composición', 'recibió', 'parece', 'original']
# total ['madre', 'historia', 'princesa', 'tercera', 'el']
# david ['segunda', 'crónica', 'leyenda', 'actualidad', 'editorial']
# science ['religiosa', 'constante', 'científica', 'aparentemente', 'tampoco']
# related ['clases', 'grado', 'adelante', 'cómo', 'vez']
# rock ['principalmente', 'originalmente', 'parece', 'tradicionalmente', 'fundamentalmente']
# railway ['pueblo', 'tamaño', 'secreto', 'daño', 'isleños']
# become ['revista', 'art', 'publicaciones', 'universidad', 'revistas']
# led ['tiempo', 'general', 'grado', 'momento', 'cómo']
# students ['independencia', 'sangre', 'electricidad', 'petróleo', ']']
# started ['graves', 'poca', 'numerosas', 'apoyo', 'muerto']
# news ['casi', 'apenas', 'prácticamente', '17', 'n']
# described ["'", 'canales', 'manera', 'donde', 'forma']
# role ['mayor', 'todo', 'ciertos', 'origen', 'hasta']
# election ['desarrollo', 'león', 'arte', 'teología', 'tratamiento']
# albums ['idioma', 'tradición', 'canción', 'viene', 'será']
# present ['pública', 'sexual', 'civil', 'humana', 'moda']
# indian ['clave', 'célula', 'victoria', 'cifra', 'cosa']
# kingdom ['”', 'destino', 'actualmente', 'ahora', 'luego']
# books ['•', 'orientación', 'antigüedad', 'fotografía', 'síntomas']
# important ['las', 'cualquier', 'productos', 'comida', 'gas']
# northern ['cabe', 'apareció', 'actualidad', 'sinopsis', 'protagonizada']
# love ['a', 'principalmente', 'fundamentalmente', 'por', 'claramente']
# canadian ['tal', 'buena', 'victoria', 'pocos', 'mismos']
# press ['impacto', 'reconocimiento', 'daños', 'daño', 'conocimiento']
# type ['hermana', 'madre', 'princesa', 'hermano', 'vasco']
# act ['vive', 'portugués', 'española', 'luego', 'paulo']
# editor ['venezuela', 'sinopsis', 'oficialmente', 'actuó', 'inicialmente']
# schools ['áfrica', '•', 'capital', 'fiestas', 'orígenes']
# program ['asociado', 'unido', 'león', 'progreso', 'empleo']
# once ['cantidad', 'formas', 'expresión', 'venta', 'voces']
# issue ['xv', 'universitaria', 'vasco', 'nº', 'mexicana']
# social ['posee', 'presenta', 'se', 'es', 'son']
# germany ['une', 'dirige', 'conocimiento', '”', 'destino']
# production ['cultura', 'tecnología', 'mitología', 'danza', 'medicina']
# male ['xxunk', 'formando', 'posee', 'formada', 'da']
# awards ['turismo', 'maíz', 'cultivo', '”', 'pesca']
# points ['energía', 'comida', 'gas', 'consumo', 'alimentos']
# similar ['clases', 'cualquier', 'paso', 'dolor', 'algunas']
# professional ['moneda', 'agricultura', 'pesca', 'cocina', 'causa']
# say ['frecuentemente', 'granada', 'activa', '*', 'oficialmente']
# background ['cocina', 'cerámica', 'arquitectura', 'física', 'química']
# enough ['adelante', 'cómo', 'cuidado', 'incluso', 'atrás']
# common ['piel', 'esclavos', 'ropa', 'sangre', 'pies']
# data ['seguridad', 'lucas', 'reacción', 'robert', 'esto']
# color ['sol', 'radio', 'du', 'personal', 'fiestas']
# better ['unión', 'relación', 'captura', 'acción', 'boca']
# person ['allí', 'atrás', 'futuro', 'alguna', 'pan']
# services ['respuesta', 'efecto', 'origen', 'tendencia', 'rápidamente']
# museum ['allí', 'ahora', 'vivir', 'deporte', 'estudiar']
# battle ['luego', 'desde', 'el', 'católica', 'española']
# sports ['fuente', 'evolución', 'naturaleza', 'autores', 'hipótesis']
# already ['plena', 'adultos', 'elegir', 'causa', 'controlar']
# currently ['lenguas', 'monumentos', 'actores', 'empresas', 'leer']
# hall ['”', '»', 'presente', 'desde', 'vive']
# buildings ['•', 'soberanía', '…', 'expansión', 'progreso']
# historic ['reforma', 'traducción', 'aparte', 'será', 'titulada']
# date ['mundo', 'portugués', 'después', 'company', 'inmediatamente']
# considered ['obligado', 'noticias', 'civil', 'conferencias', 'especial']
# change ['alimentos', 'alrededor', 'allí', 'etc', 'azúcar']
# location ['después', 'social', 'militar', 'mayor', 'luego']
# seems ['adelante', 'vez', 'clases', 'trayectoria', 'tarde']
# must ['línea', 'bajo', 'caballería', 'oposición', 'clase']
# our ['pero', 'aunque', 'compuesta', 'formada', 'que']
# southern ['cabe', 'apareció', 'actualidad', 'sinopsis', 'versión']
# lost ['o', 'especial', 'reducción', 'etc', 'independencia']
# something ['conocida', 'considerada', 'dedicada', 'integrada', 'dividida']
# together ['iv', 'company', 'university', 'man', 'vii']
# robert ['actualidad', 'leyenda', 'segunda', 'editorial', 'versión']
# fact ['tres', 'famoso', 'fallecido', 'convertido', 'nº']
# less ['posee', 'muestra', 'tiene', 'comprende', 'tendrá']
# japanese ['altos', 'porcentaje', '24', 'cierto', 'agente']
# groups ['costumbres', 'mitología', 'educación', 'áfrica', 'high']
# content ['gas', 'la', 'fútbol', 'ácido', 'fauna']
# board ['ahora', 'desde', 'educación', 'compositor', 'vive']
# japan ['”', 'allí', 'dirige', ']', 'fin']
# control ['desde', 'otra', 'otro', 'al', 'otras']
# policy ['ser', 'patrimonio', 'lengua', 'virgen', 'musical']
# modern ['aparece', 'había', 'apareció', 'figura', 'se']
# human ['sierra', 'trinidad', 'laguna', 'formada', 'descendientes']
# half ['ciencia', 'dr', 'cristiana', 'religiosa', 'vasco']
# design ['costumbres', 'pan', 'danza', 'literatura', 'tradiciones']
# event ['psoe', 'asociado', 'consumo', 'futuro', 'público']
# events ['mayor', 'educación', 'áfrica', 'capital', 'clima']
# available ['atrás', 'paulo', 'dolor', 'oxígeno', 'cómo']
# done ['occidental', 'hasta', 'mayor', 'productos', 'rápidamente']
# washington ['espiritual', 'acerca', 'frente', 'restauración', 'dedicado']
# real ['para', 'probablemente', 'data', 'negra', 'lo']
# start ['iv', 'quién', 'otro', 'vasco', 'xii']
# personal ['mancha', 'cocina', 'rosa', 'ave', 'fuente']
# action ['comida', 'gas', 'principalmente', 'inmediatamente', 'energía']
# space ['aparte', 'salud', 'casado', 'evolución', 'jr']
# areas ['educación', 'mitología', 'cultura', 'historia', 'high']
# star ['comúnmente', 'previamente', 'anteriormente', 'mas', 'tampoco']
# really ['región', 'provincia', 'ciudad', 'isla', 'formando']
# china ['conocimiento', 'abogado', 'dirige', 'funcionamiento', 'allí']
# possible ['esperanza', 'amistad', 'voz', 'origen', 'dolor']
# paul ['crónica', 'versión', 'leyenda', 'real', 'oficial']
# working ['británica', 'mexicana', 'europeas', 'española', 'chilena']
# taken ['acero', 'moda', 'pan', 'cobre', 'baja']
# far ['fabricación', 'mezcla', 'decoración', 'elaboración', 'explotación']
# going ['adelante', 'cómo', 'importancia', 'comienzo', 'cuidado']
# minister ['ahora', 'pertenece', 'actualmente', 'hoy', 'nació']
# lake ['aparte', 'actualidad', 'evolución', 'década', 'respectivamente']
# reported ['poca', 'propiedades', 'colombia', 'frecuentemente', 'aguas']
# popular ['alrededor', 'símbolos', 'esclavos', 'enlaces', 'objetos']
# married ['mismo', 'cabe', 'parece', 'sería', 'comúnmente']
# founded ['textos', 'casos', 'negocios', 'sitios', '37']
# europe ['destino', 'une', 'turismo', 'actualmente', 'funciona']
# author ['actualmente', 'anteriormente', 'recientemente', 'destaca', 'cabe']
# away ['madera', 'pan', 'cobre', 'hierro', 'cerámica']
# independent ['solamente', 'letra', 'mary', 'palabra', 'italia']
# process ['alemán', 'francés', 'inglés', 'italiano', 'company']
# teams ['…', 'seguridad', 'conciencia', 'comportamiento', 'gran']
# character ['hacia', 'origen', 'cómo', 'futuro', 'al']
# low ['rick', 'lengua', 'dr', 'john', 'reina']
# michael ['crónica', 'segunda', 'actual', 'leyenda', 'destaca']
# light ['reina', 'hermana', 'virgen', 'media', 'lengua']
# big ['actualidad', 'aparte', 'asunción', 'segunda', 'versión']
# seen ['hierro', 'peces', 'pan', "'", 'acero']
# release ['política', 'literatura', 'cultura', 'social', 'león']
# episode ['libre', 'hacia', 'definitivamente', 'luego', 'posteriormente']
# wrote ['múltiples', 'dominicana', 'democrática', 'ciertas', 'buenas']
# republic ['ahora', 'deporte', 'vivir', 'destino', '”']
# thomas ['segunda', 'leyenda', 'actualidad', 'versión', 'oficial']
# companies ['juventud', 'dominio', 'personalidad', 'poderes', 'orientación']
# via ['escritos', 'carrera', 'scott', 'publicaciones', 'página']
# russian ['pierre', 'tony', '¿', 'walter', 'north']
# put ['necesaria', 'útil', 'económico', 'económicas', 'económica']
# race ['progreso', 'consumo', 'medicina', 'asociado', 'hacia']
# worked ['sean', 'paulo', 'colombia', 'mexicana', 'méxico']
# route ['león', 'dolor', 'elevado', 'tejido', 'ingeniero']
# recorded ['64', '1953', '1970', '55', '1980']
# someone ['trabajando', 'diego', 'primeras', 'mala', 'defensa']
# civil ['prensa', 'editorial', 'crítica', 'dictadura', 'críticos']
# police ['energía', 'asistencia', 'moneda', 'inmigrantes', 'deuda']
# charles ['leyenda', 'editorial', 'crónica', 'organización', 'versión']
# eastern ['cabe', 'actualidad', 'trama', 'hubo', 'aparte']
# body ['cd', 'psoe', 'voz', 'd.', 'inglés']
# question ['último', 'tercero', 'ámbito', 'castilla', 'concepto']
# italian ['símbolo', 'cruz', 'little', 'salió', 'les']
# featured ['1970', '1980', '1990', '1920', '1950']
# week ['definitivamente', 'nuevamente', 'inmediatamente', 'rápidamente', 'asociado']
# texas ['comarca', 'parroquia', 'estatus', 'legislatura', 'vivienda']
# chief ['hay', 'cabe', 'existe', 'griega', 'existen']
# close ['grado', 'clases', 'cómo', 'algunas', 'algunos']
# match ['internacional', 'americana', 'electrónica', ',', 'libre']
# roman ['incluida', 'columbia', 'editorial', 'seguido', 'clave']
# come ['esperanza', 'alta', 'mala', 'pérdida', 'poca']
# opened ['petróleo', 'especiales', 'carbón', '25', '64']
# tour ['”', 'turismo', '»', 'patrimonio', 'mejor']
# sea ['>', 'descrito', 'center', '”', 'clima']
# cross ['estudiar', 'aun', 'todos', 'seguir', 'saber']
# playing ['buenos', 'independencia', '64', '200', 'guerra']
# health ['producción', 'composición', 'enlaces', 'fauna', 'fiestas']
# institute ['ahora', 'vive', 'continúa', 'nunca', 'presente']
# forces ['áfrica', '…', '•', '¿', 'ángel']
# green ['aparte', 'india', 'naturaleza', 'misma', 'era']
# rights ['después', 'tras', 'incluso', 'finalmente', 'si']
# evidence ['c.', 'el', 'f.', 'uno', 'b.']
# originally ['renta', 'opción', 'plena', 'triple', 'voto']
# aircraft ['?', 'impacto', 'daño', 'legado', 'hacia']
# arts ['consecuencia', 'fauna', 'vegetación', 'playa', ']']
# range ['dr', 'historia', 'madre', 'educación', 'tercera']
# probably ['bahía', 'us', 'santa', 'escuelas', 'liberales']
# problem ['fútbol', 'hasta', 'mundo', 'imperio', 'romano']
# issues ['mejor', 'patrimonio', 'principal', 'directora', 'arquitectura']
# average ['dr', 'voz', 'letra', 'hermana', 'lengua']
# network ['más', 'primero', 'durante', 'algo', '…']
# win ['moda', 'animación', 'lectura', 'artículos', 'conferencias']
# shows ['misiones', 'zamora', 'negocios', 'love', 'reformas']
# wife ['también', 'oficialmente', 'nuevamente', 'latino', 'trayectoria']
# returned ['cómo', 'grado', 'algunos', 'contrario', 'clases']
# night ['mayor', 'company', '—', '―', 'también']
# magazine ['fin', 'alguna', 'inmediato', 'definitiva', 'ciertas']
# centre ['clima', 'finalmente', 'luego', 'rico', 'argentino']
# usually ['marina', 'judíos', 'adultos', 'hombres', 'mujeres']
# elected ['buena', 'general', 'uso', 'especialmente', 'cierta']
# able ['adelante', 'cómo', 'clases', 'importancia', 'vez']
# stage ['―', '—', '/', ',', 'do']
# ireland ['une', '”', 'va', 'testamento', ']']
# today ['conocimiento', 'testamento', 'etc', 'abogado', 'definitivamente']
# academy ['qué', 'natural', 'nunca', 'romano', 'filosofía']
# saint ['simplemente', 'tradicionalmente', 'sea', 'alfonso', 'así']
# self ['cristiana', 'humana', 'religiosa', 'griega', 'católica']
# continued ['cómo', 'adelante', 'clases', 'algunos', 'vez']
# stations ['soberanía', 'continuación', 'integración', 'rodaje', '1970']
# mother ['también', 'nº', 'artístico', 'argentino', 'como']
# appeared ['hasta', 'allí', 'ciertos', 'dichos', 'dichas']
# africa ['une', '”', 'vivienda', 'paisaje', 'caracteriza']
# culture ['cerámica', 'escultura', 'arquitectura', 'fauna', 'economía']
# spanish ['opción', '48', 'salió', 'duró', '22']
# grand ['actualidad', 'editorial', 'segunda', 'versión', 'década']
# committee ['día', '”', 'responsable', 'fruto', 'historiador']
# things ['frontera', 'baja', 'alta', 'trinidad', 'región']
# fire ['comida', 'pan', 'hacia', 'cobre', 'electricidad']
# changed ['posibilidad', 'papel', 'reducción', 'realizando', 'raíces']
# gold ['mientras', 'haya', 'personas', 'aves', 'presentes']
# female ['xxunk', 'laguna', 'cueva', 'jardines', 'boca']
# course ['iv', 'nº', 'vasco', 'otro', 'xv']
# directed ['sonora', 'fuese', 'proviene', 'usa', 'indica']
# months ['cultura', 'geografía', 'mejor', 'trayectoria', 'pensamiento']
# chinese ['hot', 'vendió', 'alas', 'pequeño', 'fuertes']
# previous ['moneda', 'meridional', 'renta', 'cápita', 'opera']
# developed ['1950', '1980', '1970', 'animación', 'televisión']
# size ['destaca', 'vive', 'actualmente', 'nº', 'c.']
# mentioned ['órganos', 'bajos', 'procesos', 'mercados', 'zonas']
# festival ['turismo', '”', '»', 'cultivo', '“']
# peter ['crónica', 'tarde', 'destacó', 'versión', 'actual']
# basketball ['lenguas', 'comparación', 'sierra', 'eran', 'situación']
# move ['libre', 'company', 'pública', 'legal', 'terror']
# performance ['hacia', 'mexicana', 'española', 'americana', 'mayor']
# standard ['es', 'santos', 'james', 'los', 'lo']
# means ['ii', 'iv', 'todo', 'nuestra', 'estar']
# give ['dictadura', 'salamanca', 'comedia', 'compañía', 'obra']
# training ['cerámica', 'para', 'alrededor', 'comida', 'normalmente']
# artist ['recientemente', 'oficialmente', 'simplemente', 'habitualmente', 'anteriormente']
# word ['y', 'e', 'que', 'para', 'formando']
# blue ['está', 'ubicada', 'formó', 'tiene', 'alrededor']
# primary ['negros', 'grupos', 'causa', 'dioses', 'británicos']
# announced ['trece', 'colombia', 'seis', 'usualmente', 'once']
# value ['ser', 'vii', 'la', 'inglés', 'dr']
# christian ['símbolo', 'considera', 'deriva', 'llama', 'tomaron']
# private ['xxunk', 'corte', 'casa', 'santos', 'boca']
# catholic ['región', 'planta', 'capa', 'dan', 'zona']
# artists ['argumento', 'expresión', 'preparación', 'disposición', 'escritura']
# includes ['new', 'gobiernos', 'time', 'publicaciones', 'sociedades']
# view ['otro', 'empresario', 'nº', 'productor', 'letras']
# almost ['familia', 'agencia', 'judíos', 'mujeres', 'confederación']
# baseball ['poblaciones', 'moneda', 'atmósfera', 'obtuvo', 'correspondiente']
# seven ['alemania', 'probablemente', 'china', 'república', 'suiza']
# appears ['ciertos', 'pie', 'atrás', 'luz', 'dolor']
# technology ['granada', 'guion', 'pablo', 'taxonomía', 'martín']
# future ['jr', 'música', 'surgió', 'localidad', 'originalmente']
# formed ['1970', '1920', '1960', '1910', '1950']
# census ['aragón', 'moderno', 'descrita', 'hollywood', '1996']
# images ['’', 'miss', 'pop', 'b.', 'a.']
# results ['esclavos', 'alimentos', 'áfrica', 'seguridad', 'pueblos']
# return ['cómo', 'algunas', 'algunos', 'adelante', 'clases']
# quality ['nacida', 'considerado', 'características', 'destaca', 'ahora']
# construction ['mujeres', 'alfonso', 'c.', 'mitología', 'española']
# zealand ['ofrece', 'dirige', 'reconocimiento', 'través', 'une']
# front ['negro', 'mujeres', 'verde', 'princesa', 'letras']
# cover ['n', '’', 'un', '12', '$']
# model ['carmen', 'universo', 'inglés', 'man', 'baloncesto']
# read ['variantes', 'inmediato', 'it', 'método', 'métodos']
# material ['comportamiento', 'terror', 'salvador', 'comunicación', 'moda']
# strong ['ayuda', 'amenaza', 'opción', 'fuente', 'esperanza']
# coach ['ejerció', 'comúnmente', 'significa', 'actuó', 'existe']
# henry ['oficial', 'dedicado', 'actual', 'del', 'real']
# mark ['actualidad', 'crónica', 'década', 'leyenda', 'versión']
# organization ['material', 'desarrollo', 'escribir', 'estudiar', 'rica']
# studies ['arquitectura', 'fauna', 'senador', '…', 'considerar']
# federal ['edward', 'gente', 'carl', 'william', 'walter']
# richard ['oficial', 'leyenda', 'versión', 'crónica', 'actual']
# virginia ['actualidad', 'utilización', 'parroquia', 'legislatura', 'asunción']
# car ['culto', 'comportamiento', 'ropa', 'terror', 'color']
# attack ['internacional', 'literario', 'económico', 'venezolano', 'colombiano']
# conference ['electricidad', 'janeiro', 'frecuencia', '¿', 'poderes']
# outside ['asimismo', 'además', 'recientemente', 'igualmente', 'canciones']
# study ['antecedentes', 'escritores', 'artistas', 'mujeres', 'todo']
# brother ['también', 'oficialmente', 'además', 'como', 'recientemente']
# names ['¿', 'todo', 'áfrica', '…', 'ciertas']
# writer ['originalmente', 'comúnmente', 'actuó', 'existe', 'cabe']
# characters ['origen', 'orientación', '•', 'mayor', 'cerámica']
# musical ['fuente', ',', 'mancha', 'guinea', 'california']
# nothing ['adelante', 'firme', 'específicamente', 'posesión', 'vista']
# border ['tema', 'baloncesto', 'fruto', 'instituto', 'aplicaciones']
# medical ['columbia', 'pero', 'países', 'aunque', 'aparte']
# countries ['legado', 'raza', 'turismo', 'geografía', 'economía']
# past ['formación', 'raza', 'producción', 'vivienda', 'integrado']
# writing ['síntomas', 'ciertas', 'productos', 'ciertos', 'métodos']
# makes ['civil', 'time', 'new', 'periódicos', 'estadounidenses']
# interest ['alimentos', 'productos', 'órganos', 'materiales', 'minerales']
# killed ['salud', 'origen', 'áfrica', 'vida', 'moda']
# medal ['desde', 'española', 'católica', 'ibérica', 'todo']
# signed ['universal', 'científica', 'crítico', 'presidencial', 'cinematográfica']
# fair ['ayuda', 'asistencia', 'voluntad', 'destrucción', 'enfermedad']
# search ['paulo', 'normalmente', 'unidas', 'unido', 'usualmente']
# bay ['aquí', 'obispo', ')', 'allí', 'madrid']
# reference ['cómo', 'menos', 'tiempo', 'grado', 'contrario']
# especially ['objetos', 'órganos', 'espacios', 'edificios', 'campos']
# library ['paisaje', 'mantenimiento', 'nacimiento', 'progreso', 'señor']
# management ['designación', 'letra', 'características', 'escritora', 'letras']
# references ['lado', 'margen', 'contrario', 'general', 'espiritual']
# features ['art', 'st', 'editor', 'organizaciones', 'civil']
# navy ['sobre', 'lugar', 'impacto', 'conocimiento', 'localizado']
# guitar ['>', 'composición', 'letra', 'antigüedad', 'mitología']
# hill ['encargado', 'doctor', 'cultivo', 'mantenimiento', 'obligado']
# sure ['funciones', 'específicamente', 'vio', 'tomás', 've']
# historical ['moneda', 'según', 'rosa', 'denominada', '$']
# lower ['posee', 'tiene', 'está', 'presenta', 'representa']
# daughter ['también', 'sinopsis', 'trayectoria', 'nº', 'oficialmente']
# appointed ['multitud', 'lima', 'jr', 'asunción', 'concepción']
# reading ['evidencia', '11', 'explotación', 'francisco', 'revolución']
# yet ['torno', 'protección', 'libertad', 'batalla', 'esperanza']
# systems ['0.02', 'amerindios', 'destrucción', 'sinopsis', 'salud']
# debut ['científica', 'británica', 'americana', 'electrónica', 'of']
# movement ['unido', 'señor', 'tratamiento', 'conocimiento', 'cuidado']
# specific ['xxunk', 'santos', 'bajo', 'boca', 'montaña']
# always ['propiedad', 'acción', 'pero', 'bajo', 'libertad']
# actor ['orígenes', 'ejerció', 'oficialmente', 'sería', 'mismo']
# natural ['sierra', 'mezcla', 'son', 'forman', 'es']
# clear ['usualmente', 'frecuentemente', '*', 'generalmente', 'usa']
# coast ['música', 'nº', 'luego', 'actualmente', 'vasco']
# got ['dictadura', 'crisis', 'opinión', 'elección', 'oposición']
# chicago ['investigación', 'clara', 'oficial', 'código', 'carl']
# championships ['restauración', 'caza', 'pesca', 'cultivo', 'turismo']
# ten ['alemania', 'originaria', 'líderes', 'energía', 'probable']
# performed ['unidos', '1990', '1980', '1910', '1950']
# individual ['plata', 'opera', 'xxunk', 'llama', 'laguna']
# designed ['blanco', 'cómo', 'negro', 'adelante', 'colombia']
# rule ['todo', 'educación', 'portugués', 'inglés', 'casado']
# lists ['comunidades', 'papeles', 'formación', 'definición', 'universo']
# paris ['consecuencia', '»', '?', 'alcalde', 'ruta']
# thought ['cómo', 'adelante', 'clases', 'pie', 'frecuentemente']
# brown ['une', 'dirige', 'pasa', 'va', 'ocupa']
# hand ['británico', 'italiano', 'peruano', ',', 'pan']
# needs ['muerto', 'poco', 'pronto', 'periodista', 'tarde']
# smith ['propósito', 'fin', 'potencial', 'cierto', 'sentido']
# generally ['hecha', 'dirigida', 'construida', 'agrupación', 'familia']
# base ['después', '―', 'luego', 'fauna', '—']
# florida ['casado', 'antigüedad', ']', 'funcionamiento', 'parroquia']
# capital ['también', 'con', 'después', 'siendo', 'mas']
# valley ['relacionado', 'ubicado', 'existencia', 'casado', 'juntos']
# bank ['en', 'desde', 'ahora', 'recibe', 'vive']
# gave ['dejado', 'páginas', 'global', 'campaña', 'time']
# ground ['amerindios', 'consumo', 'turismo', 'terror', 'comida']
# reached ['elección', 'opinión', 'palabras', 'dichas', 'inmediato']
# italy ['une', 'dirige', 'conocimiento', 'destino', 'funciona']
# energy ['salud', 'composición', 'mancha', 'producción', 'familia']
# leader ['otro', 'otra', 'también', 'otros', 'algunas']
# active ['productos', 'esclavos', 'inmigrantes', 'seres', 'alimentos']
# block ['estudios', 'representaciones', 'cuadro', 'aspecto', 'músicos']
# bridge ['mantenimiento', 'daño', 'senador', 'dolor', 'paisaje']
# families ['belleza', 'flora', 'school', 'fiestas', 'feria']
# changes ['alimentos', 'ciertos', 'algún', 'bienes', 'atención']
# followed ['msnm', 'china', 'colonial', 'tropical', 'americano']
# industry ['salud', 'composición', 'raza', 'puebla', 'vivienda']
# collection ['idioma', 'el', 'uno', 'la', 'c.']
# request ['nuestro', 'xvii', 'cerebro', 'musical', 'cristo']
# soon ['pesca', 'órgano', 'café', 'producto', 'ellos']
# olympic ['pared', 'capa', 'similares', 'hipótesis', 'sola']
# sold ['buenos', 'productos', 'recursos', 'alimentos', 'energía']
# writers ['•', 'representante', 'nuevo', 'dada', 'fiesta']
# professor ['existe', 'ahora', 'hay', 'sonora', 'anteriormente']
# studio ['científica', 'and', 'chilena', 'infantil', 'canadiense']
# mexico ['municipio', 'obispo', '”', 'día', '>']
# competition ['comportamiento', 'petróleo', 'progreso', 'terror', 'empleo']
# campaign ['consumo', 'teología', 'progreso', 'mantenimiento', 'deporte']
# theatre ['metal', 'papa', 'maíz', 'vegetación', 'béisbol']
# particular ['caracteriza', 'da', 'lleva', 'ocupa', 'sirve']
# empire ['obispo', 'ubicado', 'destino', '”', 'localizado']
# length ['historia', 'guitarrista', 'dr', 'nº', 'c.']
# islands ['”', 'turismo', '?', 'obispo', '–']
# singer ['aún', 'resulta', 'parece', 'ejerció', 'anteriormente']
# create ['revista', 'art', 'revistas', 'editor', 'universidades']
# additional ['renta', 'georgia', 'moneda', 'negros', 'causa']
# soviet ['web', 'tom', 'presentes', 'kg', 'douglas']
# market ['enlaces', 'taxonomía', 'producción', 'alimentación', 'salud']
# words ['sur', 'democrática', 'qué', 'latina', 'oeste']
# producer ['recientemente', 'originalmente', 'anteriormente', 'sinopsis', 'oficialmente']
# notes ['estar', 'numerosas', 'ii', 'varias', 'vii']
# novel ['técnica', 'méxico', 'nuevamente', 'simplemente', 'chile']
# code ['estudiar', 'rico', 'aumentar', 'estar', 'su']
# fourth ['casi', 'las', 'pocos', 'ciertos', 'aproximadamente']
# sport ['conservación', 'plantas', 'pintura', 'retiro', 'publicidad']
# van ['actualidad', 'aparte', 'misma', 'versión', 'estuvo']
# mary ['actual', 'dedicado', 'fin', 'acerca', 'crónica']
# airport ['center', 'obispo', 'testamento', 'progreso', 'conocimiento']
# sound ['iv', 'en', 'company', '/', 'parcialmente']
# status ['paulo', 'fauna', 'televisión', 'company', 'luego']
# irish ['22', 'murieron', 'señal', '11', '25']
# child ['—', 'asociado', 'mayor', 'do', 'center']
# idea ['nº', 'idioma', 'otro', 'quién', 'iv']
# foreign ['sierra', 'irlanda', 'república', 'atmósfera', 'región']
# register ['latinoamérica', 'eso', 'bolivia', 'américa', 'ese']
# eight ['alemania', 'probablemente', 'hombres', 'según', 'república']
# problems ['razas', 'mejor', 'formación', 'industria', 'high']
# native ['versión', 'aparte', 'titulada', 'comúnmente', 'muy']
# ...
# dna ['young', 'little', 'instrumentos', 'universo', 'adams']
# carbon ['santos', 'xxunk', 'eran', 'bahía', 'laguna']
# boats ['•', 'significado', 'relación', 'são', 'aspecto']
# visitors ['pedro', 'batería', 'verdad', 'destrucción', 'juana']
# plate ['imágenes', 'cerca', 'leer', 'blanco', 'superiores']
# hunt ['pasando', 'entró', 'relativamente', 'ver', 'descubre']
# ride ['relacionado', 'señora', 'concentración', 'leer', 'fruto']
# terminus ['xix', 'superior', 'propios', 'xv', 'universitaria']
# balance ['quinto', 'uno', 'baloncesto', 'ubicación', 'latín']
# usual ['calles', 'infancia', 'observación', 'protección', 'considerar']
# arrival ['menor', 'xv', '’', 'b', 'último']
# cargo ['esperanza', 'ayuda', 'utilizada', 'más', 'da']
# feed ['disponibles', 'femenino', 'realizadas', 'relacionadas', 'descubierto']
# childhood ['[', 'pobreza', 'próximo', 'feria', 'festival']
# accompanied ['china', 'h.', 'j.', 'm.', 'colonial']
# honour ['conocidas', 'sonido', 'presente', 'amigos', 'miguel']
# soil ['dirección', 'king', 'obras', 'dibujo', 'estableció']
# possibility ['idioma', 'ii', 'hermano', 'considerada', 'vasco']
# styles ['continuación', 'sucesor', 'servicios', 'playa', 'teología']
# considerable ['presencia', 'permite', 'flor', 'utiliza', 'sierra']
# lose ['independientes', 'completa', 'international', 'dulce', 'asturias']
# sweet ['dada', 'humanidad', 'realizada', 'enfermedad', 'caída']
# operational ['nobles', 'naturaleza', 'esclavos', 'agrícola', 'infraestructura']
# tall ['h.', 'verdad', 'reducción', 'sonido', 'organismo']
# constitutional ['fórmula', 'denominada', 'plantas', 'caída', 'tony']
# fruit ['compuesto', 'fundó', 'afroamericanos', 'genérico', 'estableció']
# depression ['zamora', 'mendoza', 'efecto', 'toledo', 'mateo']
# perspective ['mexicano', 'oriente', 'concepto', 'descubrimiento', 'constitucional']
# resident ['misma', 'especialmente', 'había', 'atmósfera', 'mismos']
# pain ['ropa', 'habla', 'instalaciones', 'limitada', 'constituyen']
# wooden ['cuadrados', 'izquierda', 'va', 'luna', 'sierra']
# missed ['ensayo', 'establecido', 'sello', 'electoral', 'reducción']
# alive ['inicialmente', 'comunicación', 'relacionado', 'funciona', 'construir']
# behaviour ['guitarra', 'gran', 'ramón', 'mediterráneo', 'manuel']
# spiritual ['santos', 'mientras', 'eran', 'murieron', 'mamíferos']
# marks ['libro', 'construcciones', 'love', 'continuar', '1990']
# animation ['significado', 'conocimientos', 'temperatura', 'cabo', 'fenómeno']
# agents ['cárcel', 'escocia', 'infancia', 'clara', 'escribió']
# statue ['jean', 'r', 'piano', 'originaria', '100']
# filed ['art', 'estadounidenses', 'hollywood', 'franceses', 'comunistas']
# jobs ['continente', 'sonido', 'imágenes', 'pinturas', 'apertura']
# cuba ['santuario', 'mente', 'avenida', 'reconstrucción', 'noche']
# aside ['palma', 'santos', 'símbolos', 'plata', 'machos']
# schedule ['festival', 'poderes', 'bolívar', 'rey', 'conciencia']
# forming ['editor', 'art', 'civil', 'películas', 'star']
# desire ['adelante', 'consecuencias', 'contrario', 'ritmo', 'grado']
# vessels ['duración', 'transformación', 'secundarios', 'arzobispo', 'fiestas']
# continental ['aspectos', 'localizado', 'hectáreas', 'cuando', 'secuencia']
# layer ['pop', 'hermano', '100', 'jazz', 'dios']
# designation ['estatal', 'radical', 'religiosas', 'lado', 'rica']
# revenue ['información', 'pedro', 'ropa', 'sevilla', 'gran']
# seeking ['tomás', 'corrientes', 'batería', 'derrota', 'zamora']
# entering ['cuentos', 'reformas', 'grabaciones', 'trabajos', 'obras']
# approval ['francisco', 'máximo', 'college', 'xx', 'embargo']
# horses ['•', 'une', 'protección', 'belleza', 'dirige']
# visiting ['poemas', 'afirmó', 'ordenó', 'mismo', 'señaló']
# supporters ['primeros', 'culturas', 'jaime', 'lenguas', '…']
# pink ['primavera', 'decide', 'buscando', 'defensa', 'quinto']
# roots ['intervención', 'david', 'distribución', 'partir', 'chris']
# premiered ['secundarios', 'adicionales', 'disponibles', 'hasta', 'celular']
# adults ['biblioteca', 'fiestas', 'localización', 'island', 'orientación']
# immediate ['colorado', 'plata', 'cabeza', 'adquirió', '16']
# strip ['amigos', 'xxfake', 'poema', 'instrumento', 'eléctrico']
# bound ['paulo', 'lucas', 'instrumentos', 'continuó', 'gabriel']
# hull ['turístico', 'localizado', 'propio', 'amistad', 'tamaño']
# origins ['castilla', 'tercer', 'siglo', 'fauna', 'ramón']
# tie ['cambiar', 'servir', 'útil', 'escribir', 'seguir']
# liberty ['marqués', 'graduó', 'fundado', 'exposición', 'sergio']
# siege ['no', 'atrás', 'bolivia', 'francés', 'todo']
# portrayed ['florida', '1975', '1959', 'lee', '1973']
# decline ['cristianos', 'ríos', 'distintos', 'ocupación', 'sangre']
# submitted ['mateo', 'premio', 'santiago', 'pérez', 'obligado']
# enterprise ['ambiente', '1943', 'escenario', 'comunicación', 'varía']
# debuted ['anuales', 'hasta', 'orientales', 'cuadrados', 'formando']
# destruction ['características', 'músico', 'considerada', 'letras', 'antecedentes']
# weapon ['caída', 'muerte', 'vicente', 'rica', 'adicional']
# viewed ['disney', 'apple', "'", 'fox', '55']
# assault ['económicas', 'internacional', 'económico', 'europeo', 'chileno']
# absence ['xvii', '’', 'dr', 'santo', 'fundada']
# tribes ['historiadores', 'asuntos', 'papeles', 'ninguno', '•']
# themes ['mitología', 'primaria', 'ácido', 'poeta', 'tradiciones']
# guards ['pueblo', 'capa', 'cristóbal', 'resolver', 'supone']
# tail ['afroamericanos', 'asesinado', 'dividido', 'tipo', 'actividad']
# decides ['clases', 'adelante', 'revolucionario', 'cantidad', 'tener']
# vessel ['diseño', 'ideal', 'coronel', 'alonso', 'próximo']
# telling ['cuba', 'renuncia', 'publicaciones', 'joan', 'puesta']
# writes ['ix', 'últimas', '*', 'antiguas', 'múltiples']
# mediterranean ['información', 'visión', 'solución', 'industria', 'pinturas']
# penalty ['recursos', 'seguir', 'uso', 'colores', 'comunicaciones']
# secure ['time', 'electo', 'garcía', 'software', 'oviedo']
# characteristics ['renacimiento', 'navarra', 'estilo', 'antigüedad', 'naval']
# falling ['electrónica', 'alternativa', 'presión', 'organizada', 'terrestre']
# rival ['trabajó', 'escribió', 'mismos', 'mismo', 'hizo']
# adaptation ['guitarrista', 'r', 'uno', 'democrática', 'b']
# exit ['descubre', 'carmen', '$', 'anna', 'rasgos']
# crowd ['tv', 'más', 'blanca', 'señor', 'completamente']
# civilian ['canción', 'carolina', 'incluida', '3', 'moneda']
# partly ['escuelas', 'roberto', 'colorado', 'pues', 'texas']
# highways ['sistema', 'pena', 'óscar', 'exposición', 'centros']
# artwork ['luis', 'peter', 'rasgos', 'asesinado', 'duración']
# occasions ['método', 'obispo', 'testamento', 'paisaje', 'hidalgo']
# struggle ['realizando', 'morir', 'pedro', 'mundo', 'nicolás']
# transition ['ojo', 'salida', 'herrera', 'contar', 'proteínas']
# legacy ['arquitectura', 'real', 'cocina', 'radio', 'españolas']
# denied ['ocupar', 'of', 'investigación', 'construcciones', 'secretaría']
# relationships ['fallecido', 'programa', 'i.', 'embajador', 'primeros']
# signing ['comedia', 'fallecido', 'literaria', 'xi', 'liderazgo']
# believes ['escuelas', 'xxfake', 'tierras', 'puesta', 'utiliza']
# reveals ['flores', 'colombia', 'funciones', 'células', 'suele']
# defeating ['resultó', 'actuó', 'apareció', 'quedó', 'sucedió']
# ranks ['cuestiones', 'plantas', 'gran', 'bautista', 'planta']
# appointment ['jazz', 'b', 'video', 'primaria', 'privada']
# sessions ['autonomía', 'retiro', 'conciencia', 'testamento', 'abogado']
# trials ['francisco', 'trabajo', 'aragón', 'presidente', 'emperador']
# mines ['servicios', 'recursos', 'aspecto', 'monumentos', 'martín']
# rapidly ['villa', 'sierra', 'guerrero', 'policía', 'artillería']
# meetings ['noche', 'embajador', 'organismo', 'feria', 'j.']
# woods ['gira', 'autor', 'rol', 'rodrigo', '1982']
# dancing ['usos', 'k', 'ofrece', 'tocar', 'reacción']
# tribute ['contrario', 'pronto', 'pérdida', 'células', 'grado']
# acted ['corte', 'donde', 'formada', 'xxunk', 'peces']
# rocks ['tu', 'historiadores', 'eliminación', '1979', 'cristóbal']
# protest ['útil', 'texas', 'universo', 'clasificación', 'habilidad']
# hunting ['observación', 'colores', 'usos', 'sangre', 'sierra']
# frequent ['boca', 'habla', 'están', 'padres', 'xxunk']
# sing ['inferior', 'noticias', 'las', 'establecimiento', 'totalmente']
# jury ['sonidos', 'actitud', 'alma', 'variedades', 'tierras']
# load ['descrito', 'jr', 'ep', 'letras', 'descrita']
# throne ['festival', 'college', 'school', 'trabajando', 'escolar']
# concerts ['fenómeno', 'expansión', 'restauración', 'creciente', 'rodaje']
# explains ['raíces', 'puesta', 'virus', 'poblaciones', 'flores']
# meat ['tiene', 'alrededores', 'lleva', 'observación', 'eran']
# moral ['es', 'desarrolla', 'tres', 'sierra', '27']
# partially ['sierra', 'mientras', 'galería', 'boca', '80']
# bright ['va', 'justicia', 'define', 'forman', 'describe']
# allies ['•', 'hijos', '_', 'índice', 'tamaño']
# reviewer ['resultó', 'martin', 'adams', 'normalmente', 'modo']
# intention ['nuestra', 'adelante', 'poco', 'santo', 'atrás']
# casualties ['económicas', 'económico', 'salvador', 'conocimiento', 'renacimiento']
# rhythm ['dependiendo', 'nada', 'representaciones', 'canadá', 'noche']
# catch ['m.', 'retirada', 'corrupción', 'riqueza', 'tormenta']
# deck ['ep', 'niño', 'pasión', 'tocar', 'cd']
# lasted ['guatemala', 'arizona', 'panamá', 'americanos', 'massachusetts']
# arrangement ['vii', 'don', 'cardenal', 'uno', 'influencias']
# diameter ['personalidad', 'nombre', 'moderno', 'muerto', 'canción']
# germans ['porcentaje', 'potencial', 'valor', '_', 'precio']
# populations ['tercer', 'university', 'presidente', 'país', 'península']
# rebellion ['celular', 'terrestre', 'escolar', 'artes', 'meridional']
# premiere ['peruano', 'menores', 'rusa', 'saber', 'xix']
# heading ['situaciones', 'calidad', 'calles', 'respuesta', 'ninguno']
# peaked ['formando', 'exterior', 'anuales', 'cuadrados', ';']
# tons ['infancia', 'alrededores', '´', '”', 'habitantes']
# apartment ['asociados', 'brasil', 'posible', 'riqueza', 'escultura']
# mario ['desaparición', 'guerrero', 'titulada', 'he', 'señora']
# shield ['desarrolla', 'tu', 'canción', 'alfredo', 'provocó']
# harbour ['unidas', 'exposiciones', 'andrés', 'usos', 'localizado']
# hitler ['localizado', 'adquirió', 'permite', 'caracteriza', 'describió']
# departure ['nacida', 'antonio', 'ramón', 'peña', 'francisco']
# occasion ['teatro', 'continente', 'relacionado', 'francisco', 'caballero']
# possession ['guitarrista', 'vi', 'hermana', 'conocida', 'd.']
# defend ['poemas', 'grabaciones', 'br', 'integrado', 'organizó']
# forty ['nunca', 'recepción', 'james', 'utilizada', 'dada']
# bases ['rodrigo', 'oscar', 'violencia', '14', 'frontera']
# lesser ['llegada', 'pierre', 'andrés', 'corea', 'infancia']
# lap ['.', 'escultura', '—', 'coro', 'junto']
# fifty ['nunca', 'tampoco', 'canadá', 'rick', 'cuando']
# favour ['considerado', 'reconocido', 'ii', 'numerosos', 'comandante']
# traveled ['oportunidad', 'ausencia', 'normal', 'estilo', 'habilidad']
# emerged ['acero', 'hierro', 'plantas', 'peces', 'aves']
# attacking ['identidad', '1975', 'mary', 'mark', 'considera']
# chorus ['desarrollo', 'semillas', 'sirve', 'noticias', 'rápidamente']
# influences ['periodista', '1936', 'renacimiento', 'henry', 'américa']
# fifteen ['cristóbal', 'asuntos', 'destacados', 'utilizada', 'eliminación']
# tale ['nunca', 'nos', 'te', 'no', 'ver']
# atmosphere ['andrés', 'school', 'propiedades', 'austria', 'jazz']
# dollars ['asiáticos', 'período', 'voluntad', 'dirigió', 'periodo']
# rough ['poblaciones', 'distancia', 'observar', 'noche', 'pinturas']
# neck ['actividad', 'dividido', 'representado', 'semillas', 'carmen']
# amounts ['ii', 'hermana', 'pop', 'esposa', 'selección']
# filming ['fenómeno', 'tendencia', 'pública', 'técnicas', 'expansión']
# danger ['padre', 'que', 'azul', 'verde', 'geográfica']
# colonies ['preparación', 'comunicaciones', 'oficinas', 'guion', 'rugby']
# winds ['madre', 'princesa', 'r', 'historia', '¡']
# gates ['sur', 'pinturas', 'pasión', 'óscar', 'doble']
# reaches ['liderazgo', 'noticias', 'xx', 'margen', 'perdido']
# orbit ['guillermo', 'madrid', '1974', 'vivo', 'cristo']
# illness ['fotografía', '2', 'amistad', 'expansión', 'toledo']
# autumn ['algo', 'verdad', '27', 'políticos', 'radiación']
# difficulty ['pueblos', 'nuevos', 'hong', 'esclavos', 'personal']
# eggs ['mezcla', 'fotografía', 'comunicación', 'visión', 'transformación']
# enemies ['xxi', 'asesinato', 'colecciones', 'generación', 'house']
# cult ['it', '26', 'tradicional', 'beneficios', '’']
# recognised ['lucas', 'taylor', 'usar', 'sonidos', 'guinea']
# preparation ['tomás', 'cuando', 'animales', 'vicente', 'santos']
# targets ['autores', 'barroco', 'fiestas', 'fotografía', 'totalmente']
# alien ['principios', 'hecha', 'mateo', 'colores', 'cárcel']
# withdrew ['utilizando', 'creando', 'palma', 'propuso', 'ingreso']
# depicted ['carga', 'rasgos', 'nuevos', 'times', '1960']
# thirteen ['ecuación', '¿', 'rick', 'jack', 'billboard']
# measured ['ejército', 'antonio', 'sonidos', '1941', 'joaquín']
# flights ['funciones', 'aquel', 'intenta', 've', 'nombre']
# temperatures ['seguridad', 'sucesor', 'código', 'novelas', 'trama']
# acres ['\n\n', '\n\n\n\n', 'descubre', '´', 'da']
# coins ['protección', 'intensidad', 'soberanía', '•', 'mención']
# oxygen ['infancia', 'andrés', 'peña', 'piedra', 'white']
# arc ['as', 'fundamental', 'duración', 'habilidad', 'aplicaciones']
# vii ['esto', 'asumió', 'actividades', '1993', 'existe']
# slaves ['hidalgo', 'infraestructura', 'virus', 'infancia', 'partir']
# symptoms ['king', 'star', 'inicios', 'film', 'completo']
# abilities ['kentucky', 'fotografía', 'caracas', 'ejemplo', 'universo']
# completing ['conceptos', 'estreno', 'sánchez', 'hall', 'compuestos']
# arriving ['orientales', 'minerales', 'óscar', 'ignacio', 'independencia']
# earning ['historiadores', 'universidades', 'novela', 'time', 'profesores']
# interchange ['directora', 'facultad', 'in', 'director', 'profesora']
# mainland ['solamente', 'historiadores', 'fundado', 'usualmente', 'br']
# negotiations ['medidas', 'acciones', 'fiestas', 'embajador', 'oficinas']
# enters ['film', 'emisión', 'grabaciones', 'canciones', 'estrenada']
# aboard ['investigaciones', 'labor', 'trabajos', 'obras', 'análisis']
# difficulties ['ropa', 'franceses', 'religiosos', 'l', 'especies']
# indies ['graduó', 'valores', 'capa', 'ingeniería', 'mitad']
# breeding ['cerámica', 'media', 'playa', 'mayor', 'cara']
# chronicle ['servicio', 'encargado', 'habilidades', 'fallecido', 'reconocimiento']
# afternoon ['humor', 'xvii', 'andalucía', 'xix', 'judicial']
# arrive ['cristóbal', 'españoles', 'materiales', 'secundarios', 'celular']
# ports ['cuestiones', '•', 'término', 'funciones', 'muestras']
# bow ['salvador', 'ideal', 'líquido', 'dibujo', 'reparto']
# travelled ['igual', 'ausencia', 'tiempo', 'oportunidad', 'especial']
# reconnaissance ['músicos', 'católicos', 'joseph', 'rayos', '25']
# prepare ['unidas', 'martín', 'pedro', 'líquido', 'miguel']
# pitched ['independencia', 'valores', 'green', 'papeles', '65']
# cannon ['plantas', 'pérdida', 'tipo', 'realiza', 'usa']
# armies ['capitán', 'gobernador', 'referirse', 'abandonar', 'destacados']
# engagement ['tema', 'arte', 'continuar', 'mal', 'virus']
# retreat ['colecciones', 'método', 'precio', 'contenido', 'pintura']
# victories ['métodos', 'herramientas', 'momentos', 'modelos', 'variaciones']
# breed ['m', 'completamente', 'territorial', 'josé', 'sonido']
# pace ['último', 'interpretada', 'construida', 'especies', 'servicios']
# moments ['construir', 'xi', 'instituciones', 'carácter', 'escapar']
# finale ['fundamental', 'territorial', 'fácilmente', 'especial', 'legal']
# spotted ['historiadores', 'sistema', 'capa', 'fundado', 'hacerse']
# wore ['españolas', 'time', 'são', 'universidades', 'franceses']
# protagonist ['desarrolla', 'entró', 'tu', 'entertainment', 'alfredo']
# intensity ['literaria', 'b.', 'ep', 'musical', 'dvd']
# audiences ['noticia', 'una', 'sector', 'transformación', 'ideas']
# kilometres ['\n\n', 'cree', 'frente', '\n\n\n', '\n\n\n\n']
# feeding ['familiares', '(', 'caracteriza', 'católicos', 'plata']
# rainfall ['alimentos', 'recursos', 'comportamiento', 'comida', 'propios']
# madonna ['fin', 'importantes', 'interés', 'sentido', 'cierto']
# specimens ['obras', 'historias', 'himno', 'r.', 's.']
# crews ['respecto', 'cristóbal', 'mamíferos', 'biblioteca', 'promover']
# 0.031007751937984496

# %%
def top_n_translation_acc(top_n=1):
    p = learn.model[0].encoder.p
    learned_embeddings = learn.model[0].encoder.p @ learn.model[0].encoder.weight
    
    hits = 0
    for k, v in en_es_dict.items():
        idx_en = vocab_en.index(k)
        diff = learn.model[0].encoder.weight - learned_embeddings[idx_en]
        candidates = diff.sum(-1).argsort(descending=False)[:top_n]
        
        for vv in v:
            idx_es = vocab_es.index(vv)
            if idx_es in candidates:
                hits += 1
                break
    return hits/len(en_es_dict)

# %%
top_n_translation_acc(100)
# Out:
# 0.03386372909016728

# %%
def top_n_translation_acc(top_n=1):
    p = learn.model[0].encoder.p
    learned_embeddings = learn.model[0].encoder.p @ learn.model[0].encoder.normalized_weight()
    
    hits = 0
    for k, v in en_es_dict.items():
        idx_en = vocab_en.index(k)
        diff = learn.model[0].encoder.normalized_weight() - learned_embeddings[idx_en]
        candidates = diff.sum(-1).argsort(descending=False)[:top_n]
        
        for vv in v:
            idx_es = vocab_es.index(vv)
            if idx_es in candidates:
                hits += 1
                break
    return hits/len(en_es_dict)

# %%
top_n_translation_acc(100)
# Out:
# 0.03223174214606283
